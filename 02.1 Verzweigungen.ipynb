# %% [markdown]
# ># **02.1 <span style="color:#f5dd42">JavaScript</span> - Verzweigungen**

# %% [markdown]
# ***

# %% [markdown]
# > ## **Verzweigungen Vergleichen mit If und Else**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Vergleichsoperatoren**

# %% [markdown]
# | Operator | Function | Funktion
# |:---------:|:-------------:|:-------------:|
# | <span style="color:#f5dd">===</span> | is equal to | ist gleich |
# | <span style="color:#f5dd">!==</span> | is not equal to | ist ungleich |
# | <span style="color:#f5dd"> > </span> | is greater than | größer als |
# | <span style="color:#f5dd"> < </span> | is lesser than | kleiner als |
# | <span style="color:#f5dd"> >= </span> | is greater or equal to | größer gleich |
# | <span style="color:#f5dd"> <= </span> | is lesser or equal to | kleiner gleich |

# %% [markdown]
# ***

# %% [markdown]
# > ### **Blitzer**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Logische Operatoren**

# %% [markdown]
# | <span style="color:#f5dd">AND</span> | <span style="color:#f5dd">OR</span> | <span style="color:#f5dd">NOT</span> |
# |:---------:|:-------------:|:--------------:|
# | && | \|\| | ! |
# | Konjunktion | Disjunktion | Negation |

# %% [markdown]
# > ### **02.2 Training Logical Operators**

# %% [markdown]
# ***

# %% [markdown]
# >## **02.1 <span style="color:#fcba03">Quest 1</span>** Odd or Even
#
# Schreiben Sie ein Programm, dass eine Zahl darauf prüft, ob sie gerade oder ungerade ist.\
# Das Ergebnis soll in einer alert() Funktion ausgegeben werden.

# %%
// 🚨 Bitte verändern Sie nicht den Code unter dieser Zeile 👇
var number = parseInt(prompt("Which number do you want to check? "));
// 🚨 Bitte verändern Sie nicht den Code über dieser Zeile 👆

// Schreiben Sie Ihren Code unter dieser Zeile 👇

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>02.1 Lösung Quest 1 Odd or Even</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# >## **02.1 <span style="color:#fcba03">Quest 2</span>** BMI 2.0
#
# Write a program that interprets the Body Mass Index (BMI) based on a user's weight and height.\
# Schreiben Sie ein Programm, dass den BMI des Benutzenden auf der Grundlage der Höhe und des Gewichtes, interpretiert.
#
# It should tell them the interpretation of their BMI based on the BMI value.\
# Es sollte dem Benutzenden den zugehörigen Text basierend auf dem Wert des BMI's ausgeben.
#
#     Under 18.5 they are underweight
#     Over 18.5 but below 25 they have a normal weight
#     Over 25 but below 30 they are slightly overweight
#     Over 30 but below 35 they are obese
#     Above 35 they are clinically obese.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>02.1 Quest 2 BMI 2.0</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# >## **02.1 <span style="color:#fcba03">Quest 3</span>** Leapyear
#
# Ist es ein Schaltjahr?\
# Schreiben Sie ein Programm, das eine Jahreszahl entgegen nimmt und überprüft\
# ob es sich bei dieser Jahreszahl um ein Schaltjahr handelt oder nicht.\
# Bitte lassen Sie das Ergebnis in der Konsole ausgeben.

# %%
// 🚨 Don't change the code below 👇
let year = parseInt(prompt("Welches Jahr möchtest du überprüfen?"));
// 🚨 Don't change the code above 👆

// Write your code below this line 👇

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>02.1 Lösung Quest 3 Leapyear</b>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# >## **02.1 <span style="color:#fcba03">Quest 4</span>** Einkommenssteuer
# Es war einmal ein schönes Land - ein Land, in dem Milch und Honig flossen\
# und in dem glückliche und wohlhabende Menschen lebten.\
# Das Glück der Menschen hatte seine Grenzen - Sie zahlten natürlich Steuern.\
# Die wichtigste Steuer, die Persönliche Einkommenssteuer (kurz: PIT),\
# musste einmal im Jahr gezahlt werden und wurde nach folgender Regel bemessen:
#
# Wenn das Einkommen des Bürgers nicht höher als 85.528 Taler war,\
# betrug die Steuer 18 % des Einkommens abzüglich 556 Taler und 2 Cent (dies war die so genannte Steuerentlastung)\
# war das Einkommen höher als dieser Betrag, betrug die Steuer 14.839 Taler und 2 Cent,\
# plus 32% des Überschusses über 85.528 Taler.
#
# Ihre Aufgabe ist es, einen Steuerrechner zu schreiben.\
# Er soll einen Fließkommawert akzeptieren: das Einkommen.\
# Dann soll er die berechnete Steuer ausgeben, gerundet auf volle Taler.
#
# Hinweis: Dieses glückliche Land gibt seinen Bürgern niemals Geld zurück.\
# Wenn die berechnete Steuer kleiner als Null ist,\
# bedeutet das nur, dass überhaupt keine Steuer anfällt (die Steuer ist gleich Null).\
# Berücksichtigen Sie dies bei Ihren Berechnungen.
#
# Schauen Sie sich den Code im Editor an, er liest nur einen Eingabewert und gibt ein Ergebnis aus,\
# also müssen Sie ihn mit einigen intelligenten Berechnungen ergänzen.

# %%
// Variant A with function

let income = parseFloat(prompt("Enter the annual income: "));
let tax;
let surplus = income - 85528;

//
// Write your code here.
//
function calcTax(income) {
  if (Number.isNaN(income)) {
    return alert("Give a valid number!");
  } else if (income >= 0 && income < 85528) {
    tax = income * 0.18 - 556.2;
    if (tax < 0) {
      tax = 0;
      return tax;
    }
    return tax;
  } else {
    tax = surplus * 0.32 + 14839.2;
    tax = Math.round(tax);
    return tax;
  }
}

/** Variant 2 without function 

let income = parseFloat(prompt("Enter the annual income: "));
let tax;
let surplus = income - 85528;

//
// Write your code here.
//
if (Number.isNaN(income)) {
  alert("Give a valid number!");
} else if (income >= 0 && income < 85528) {
  tax = income * 0.18 - 556.2;
  if (tax < 0) {
    tax = 0;
    tax;
  }
  tax;
  alert(`Tax is: ${tax}`);
} else {
  tax = surplus * 0.32 + 14839.2;
  tax = Math.round(tax);
  alert(`Tax is: ${tax}`);
}
 */

/** Martin's solution

let income = parseFloat(prompt("Gib dein Jahresgehalt ein..."));
let tax;
let surplus;

if (income <= 85528) {
  tax = (income / 100) * 18;
  tax = tax - 556.02;
} else if (income > 85528) {
  surplus = income - 85528;
  surplus = (surplus / 100) * 32;
  tax = 14839.02 + surplus;
}

if (tax <= 0) {
  tax = 0;
}

tax = Math.round(tax);
alert(`The tax is:  ${tax} thalers`);
*/

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>02.1 Lösung Quest 4 Einkommenssteuer</b>
# </div>
