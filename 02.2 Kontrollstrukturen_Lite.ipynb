# %% [markdown]
# ># **02.2 <span style="color:#f5dd42">JavaScript</span> - Kontrollstrukturen Lite**

# %% [markdown]
# ***

# %% [markdown]
# >### **Falldauer berechnen**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# >### **Wurfweite berechnen**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > #### **Umrechnung von Grad zu Bogenmaß**
#
# * JavaScript rechnet intern mit dem Bogenmaß nicht mit Gradeinheiten
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > #### **Runden**

# %% [markdown]
# ***

# %% [markdown]
# > ### **Spiel Szenario**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > ## **Zählerschleife For Loop**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Random**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Math.random(); generiert einen zufälligen Wert zwischen 0 und 0.99999999999

# %% [markdown]
# n * 6 ändert den Wertebereich auf 0 - 5.999999999999999

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
