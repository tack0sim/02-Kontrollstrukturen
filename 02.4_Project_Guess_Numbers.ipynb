# %% [markdown]
# ># **02.4 <span style="color:#3dbdac">Project</span> Guess Numbers**

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Meine erste Seite mit JavaScript</title>
</head>
<body>
    <script>
        alert("Hello World");
    </script>
</body>
</html>

# %% [markdown]
# ***

# %% [markdown]
# > ## **Spiel Szenario Zahlen Raten**
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# [Zahlen Raten Game](https://creativeryu.github.io/GuessNumbers/)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Entwicklung des Spiels**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Weiterhin soll ein Hinweis für den Spieler eingebaut werden.\
# Dieser Hinweis gibt an ob die geratene Zahl zu groß oder zu klein ist.

# %% [markdown]
# > ## **Debugging**
#
# Was genau passiert hier in unserem Code? Was für Ergebnisse werden berechnet?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# > ## **do-while Schleife**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# Optionale Anpassungen: Anzahl der Versuche begrenzen
# * mehrere Bedingungen verknüpfen
